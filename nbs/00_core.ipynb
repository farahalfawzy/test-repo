# %% [markdown]
# # newpyfile
#
# > Fill in a module description here

# %%
# !pip install nbdev
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.6 MB/s eta 0:00:00
# ...

# %%
# !nbdev_export
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/nbdev_export", line 8, in <module>
#     sys.exit(nbdev_export())
#              ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastcore/script.py", line 125, in _f
#     return tfunc(**merge(args, args_from_prog(func, xtra)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nbdev/doclinks.py", line 153, in nbdev_export
#     if not is_nbdev(): raise Exception('`nbdev_export` must be called from a directory within a nbdev project.')
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Exception: `nbdev_export` must be called from a directory within a nbdev project.

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipython-input-1049215.py in <cell line: 0>()
#       1 #| hide
# ----> 2 import nbdev; nbdev.nbdev_export()
#
# /usr/local/lib/python3.12/dist-packages/fastcore/script.py in _f(*args, **kwargs)
#     114     def _f(*args, **kwargs):
#     115         mod = inspect.getmodule(inspect.currentframe().f_back)
# --> 116         if not mod: return func(*args, **kwargs)
#     117         if not SCRIPT_INFO.func and mod.__name__=="__main__": SCRIPT_INFO.func = func.__name__
#     118         if len(sys.argv)>1 and sys.argv[1]=='': sys.argv.pop(1)
#
# /usr/local/lib/python3.12/dist-packages/nbdev/doclinks.py in nbdev_export(path, procs, **kwargs)
#     151     "Export notebooks in `path` to Python modules"
#     152     if os.environ.get('IN_TEST',0): return
# ...

# %%
#| export

print ("hello world")
# Out:
# hello world
